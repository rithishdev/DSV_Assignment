# %% [markdown]
# <a href="https://colab.research.google.com/github/rithishdev/DSV_Assignment/blob/main/DSV_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#24BAD099 - Rithish A
import pandas as pd
import matplotlib.pyplot as plt

file_path = "happiness_2017.csv"
df = pd.read_csv(file_path)

print("\nDataset Loaded Successfully!\n")

print(" DESCRIPTIVE STATISTICS \n")
print(df.describe(include="all"))

df.describe(include="all").to_csv("descriptive_statistics.csv")

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = df.select_dtypes(include=["object"]).columns


#Histograms
for col in numeric_cols:
    plt.figure()
    plt.hist(df[col].dropna(), bins=20)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

#Box Plots
for col in numeric_cols:
    plt.figure()
    plt.boxplot(df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.ylabel(col)
    plt.show()

#Line Plots
for col in numeric_cols:
    plt.figure()
    plt.plot(df[col])
    plt.title(f"Line Plot of {col}")
    plt.xlabel("Index")
    plt.ylabel(col)
    plt.show()

#Bar Plots
for col in categorical_cols:
    plt.figure()
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Bar Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

#Scatter Plots
for i in range(len(numeric_cols)):
    for j in range(i+1, len(numeric_cols)):
        x = numeric_cols[i]
        y = numeric_cols[j]

        plt.figure()
        plt.scatter(df[x], df[y])
        plt.title(f"Scatter Plot: {x} vs {y}")
        plt.xlabel(x)
        plt.ylabel(y)
        plt.show()

#Correlation Heatmap
if len(numeric_cols) > 1:
    corr = df[numeric_cols].corr()

    plt.figure(figsize=(10, 8))
    plt.imshow(corr)
    plt.colorbar()
    plt.xticks(range(len(numeric_cols)), numeric_cols, rotation=90)
    plt.yticks(range(len(numeric_cols)), numeric_cols)
    plt.title("Correlation Heatmap")
    plt.tight_layout()
    plt.show()

#Pie Charts
for col in categorical_cols:
    plt.figure()
    df[col].value_counts().plot(kind="pie", autopct="%1.1f%%")
    plt.title(f"Pie Chart of {col}")
    plt.ylabel("")
    plt.show()


print("\nAll plots generated successfully!")
print("Descriptive statistics saved as descriptive_statistics.csv")
# Out:
# Dataset Loaded Successfully!
#
#  DESCRIPTIVE STATISTICS
#
#        Country              Region      Rank  HappinessScore  Life Ladder  \
# count      140                 140  140.0000      142.000000   140.000000
# unique     140                  10       NaN             NaN          NaN
# top     Norway  Sub-Saharan Africa       NaN             NaN          NaN
# freq         1                  33       NaN             NaN          NaN
# mean       NaN                 NaN   70.5000        5.368702     5.491702
# std        NaN                 NaN   40.5586        1.159151     1.122178
# min        NaN                 NaN    1.0000        1.109750     2.661718
# 25%        NaN                 NaN   35.7500        4.537500     4.636694
# 50%        NaN                 NaN   70.5000        5.302000     5.586507
# 75%        NaN                 NaN  105.2500        6.152250     6.278276
# max        NaN                 NaN  140.0000        7.537000     7.788252
#
# ...
